# %% [markdown]
# # Formal Verification — Dev Log
#
# ## Objetivo
#
# Extração real e honesta do item "Formal Verification Layer (TLA+/Alloy/Coq)"
# do V3: **model checking por enumeração exaustiva** de um espaço de estados
# finito — não uma prova simbólica, mas uma técnica de verificação formal real
# e estabelecida (bounded model checking) quando o domínio é pequeno o
# bastante para enumerar.

# %%
import sys
from pathlib import Path

REPO_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from core.formal_verification.tribunal_properties import verify_tribunal_deny_precedence

result = verify_tribunal_deny_precedence(max_decisions=3)
print(f"Propriedade: {result.property_name}")
print(f"Casos verificados: {result.total_cases_checked}")
print(f"Se sustenta em todos os casos? {result.holds}")
print(result.summary)
# Out:
# Propriedade: agent_tribunal: DENY sempre vence quando presente na entrada
# Casos verificados: 4368
# Se sustenta em todos os casos? True
# Propriedade 'agent_tribunal: DENY sempre vence quando presente na entrada' se sustenta em TODOS os 4368 caso(s) do espaço de estados enumerado.

# %% [markdown]
# 4.368 combinações verificadas EXAUSTIVAMENTE (não amostradas) — todas as
# formas possíveis de até 3 `PolicyDecision` concorrentes na grade completa de
# 4 status x 4 níveis de risco. A invariante de segurança mais crítica do
# `agent_tribunal` (DENY nunca é "diluído") se sustenta em 100% dos casos.
#
# ## Testes e Handoff
#
# ```
# "C:/Users/Yuri_/.venvs/athenagov-ai/Scripts/python.exe" -m pytest core/formal_verification/tests -v
# ```
#
# 6/6 testes passando. **Escopo honesto**: não é TLA+/Alloy/Coq (prova
# simbólica de espaço infinito) — é enumeração de força bruta, válida só para
# domínios finitos e pequenos como este.
